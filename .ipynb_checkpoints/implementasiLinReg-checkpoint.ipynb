# %%
import numpy as np
import pandas as pd
import pylab as pl #untuk plotting
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
data = pd.read_csv('data/FuelConsumptionCo2.csv')

data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = pd.read_csv('data/dFuelConsumptionCo2.csv')
#       3 data.head()
#
# File D:\ProgramFiles\Anaconda\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\ProgramFiles\Anaconda\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
cdata = data[['pengalaman','jumlah_unggahan','tingkat_interaksi','jumlah_pengikut']]
cdata.head(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 cdata = data[['pengalaman','jumlah_unggahan','tingkat_interaksi','jumlah_pengikut']]
#       2 cdata.head(1)
#
# File D:\ProgramFiles\Anaconda\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File D:\ProgramFiles\Anaconda\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
# ...

# %%
#Kita plot hubungannya

plt.scatter(cdata.jumlah_unggahan, cdata.jumlah_pengikut,  color='red')
plt.xlabel("Jumlah Unggahan")
plt.ylabel("pengikut")
plt.show()

# %%
#Kita plot hubungannya

plt.scatter(cdata.tingkat_interaksi, cdata.jumlah_pengikut,  color='green')
plt.xlabel("Interaksi")
plt.ylabel("Pengikut")
plt.show()

# %%
#Membagi data

msk = np.random.rand(len(data)) < 0.8
train = cdata[msk]
test = cdata[~msk]

# %%
plt.scatter(train.tingkat_interaksi, train.jumlah_pengikut,  color='blue')
plt.xlabel("Interaksi")
plt.ylabel("Pengikut")
plt.show()

# %%
#Membuat model regresi
regr = LinearRegression()
train_x = np.asanyarray(train[['tingkat_interaksi']])
train_y = np.asanyarray(train[['jumlah_pengikut']])
regr.fit (train_x, train_y)

# Koefisien model
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[5.40399386]]
# Intercept:  [152.57757296]

# %%
#Plot hasil regresi

plt.scatter(train.tingkat_interaksi, train.jumlah_pengikut,  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("Interaksi")
plt.ylabel("Pengikut")
# Out:
# Text(0, 0.5, 'Pengikut')

# %%
#Menghitung error

from sklearn.metrics import r2_score

test_x = np.asanyarray(test[['tingkat_interaksi']])
test_y = np.asanyarray(test[['jumlah_pengikut']])
test_y_ = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y_ , test_y) )
# Out:
# Mean absolute error: 408.88
# Residual sum of squares (MSE): 275889.20
# R2-score: -668.61
