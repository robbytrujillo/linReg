# %%
# import library
import numpy as np
import pandas as pd
import pylab as pl #untuk plotting
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
# load data
data = pd.read_csv('data/cakar-ihbs.csv')
data.head(9)
# Out:
#                         nama  \
# 0          Nuro Azlina Puadi
# 1         Shabrina Ainimeiko
# 2          Fauzi Anis Nazhip
# 3          Nadia Chairunnisa
# 4                      Afian
# 5               Ahmad Wildan
# 6                     Habibi
# 7           Ayu siti fatimah
# 8  Muhammad Rendy Arifiyanto
#
#                                               alamat               kota  \
# 0                         Jl. Koperasi No. 79 Aikmel   Lombok Timur NTB
# 1                    Jl. Jawa II Blok N5/6 Reni Jaya      Kec. Pamulang
# 2                             Jl. Jend A Yani Lr. 15           Makassar
# 3              Jl. Pepaya IV No.18A Cengkareng Barat      Jakarta Barat
# 4                       Jalan Musa Karim Salu Karema             Majene
# 5                       Jl. Lebak bulus dalam No. 11    Jakarta Selatan
# 6  Jl. Sultan Agung Tirtayasa Kp.Sipon RT/RW 04 0...      Serang Banten
# 7                    Perumahan Graha Arradea Dramaga              Bogor
# 8   Kp.Pasir hayam Rt.03/01 Desa Sirnagalih Kec.C...            Bandung
#
#     nomor_telepon                         email      universitas/sekolah_asal  \
# 0   6285640419208      azlinafuadi571@gmail.com   Bina Madani Putri Magelang
# 1   6285710711806          sainimeiko@gmail.com                 LIPIA Jakarta
# 2   6282350645243         Fauzianis24@gmail.com                 LIPIA Jakarta
# 3   6285761063974       nchairunnisa7@gmail.com    Universitas Negeri Jakarta
# 4   6285340618670      alfianalbungsu@gmail.com       STIKES Marendeng Majene
# 5    628551875559       wildanahmaf19@gmail.com         Institut PTIQ Jakarta
# 6   6285779867203         habiebee.it@gmail.com   Islamic Center Wadi Mubarak
# 7  62895378578282   fatimah13.ayusiti@gmail.com        Universitas Ibn Kaldun
# 8   6281218552477         asrirendi76@gmail.com           Universitas Terbuka
#
#                      jurusan   IPK                          riwayat_pekerjaan  \
# 0                        IPA  3.43                 Bina Madani Putri Magelang
# 1                Bahasa Arab  4.60                   Al Buruj Learning Center
# 2                Bahasa Arab  4.80                      SD Al-Fallah kalibata
# 3       Pendidikan Sosiologi  3.64                             SMA 25 Jakarta
# 4                    Perawat  3.92       Klinik Badr Alkhaleej Medical Center
# 5       Manajemen Pendidikan  3.51                             SMP Al Madinah
# 6   Ilmu Al-Quran Dan Tafsir  2.64                 SMP Ponpes Riyadusshalihin
# 7            Ekonomi Syariah  3.69   SMP Pondok Media Islamic Boarding School
# 8          Ilmu Perpustakaan  2.00       Sekolah Dasar Negeri Merdeka Bandung
#
#    pengalaman posisi_yang_dilamar  nilai_psikotest media_sosial  \
# 0           1           Musyrifah               82    Instagram
# 1           1    Guru Bahasa Arab               80      Twitter
# 2           3    Guru Bahasa Arab               60     Facebook
# 3           3      Guru Sosiologi               65     LinkedIn
# 4           1         Petugas UKS               75     Facebook
# 5           3             Musyrif               80    Instagram
# 6           2             Musyrif               80      Twitter
# 7           1        Guru Umum SD               67     Facebook
# 8           3          Pustakawan               85     LinkedIn
#
#    jumlah_unggahan  tingkat_interaksi  jumlah_pengikut jenis_konten  \
# 0               16                 15              100      Positif
# 1               19                 23               80      Positif
# 2                1                  1                1      Negatif
# 3               10                 12               80     Campuran
# 4               20                 15              100      Positif
# 5               24                 20               95      Positif
# 6               20                 10              100      Negatif
# 7               15                 20               95     Campuran
# 8               10                 50               90      Positif
#
#    rekomendasi
# 0     Diterima
# 1     Diterima
# 2      Ditolak
# 3      Ditolak
# 4     Diterima
# 5     Diterima
# 6      Ditolak
# 7      Ditolak
# 8     Diterima

# %%
data.rekomendasi.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 data.rekomendasi.unique()
#
# File D:\ProgramFiles\Anaconda\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rekomendasi'

# %%
cdata = data[['IPK','nilai_psikotest','jumlah_unggahan','jumlah_pengikut']]
cdata.head(9)
# Out:
#     IPK  nilai_psikotest  jumlah_unggahan  jumlah_pengikut
# 0  3.43               82               16              100
# 1  4.60               80               19               80
# 2  4.80               60               13               90
# 3  3.64               65               10               80
# 4  3.92               75               20              100
# 5  3.51               80               24               95
# 6  2.64               80               20              100
# 7  3.69               67               15               95
# 8  2.00               85               10               90

# %%
#Kita plot hubungannya

plt.scatter(cdata.IPK, cdata.jumlah_pengikut,  color='red')
plt.xlabel("IPK")
plt.ylabel("pengikut")
plt.show()

# %%
#Kita plot hubungannya

plt.scatter(cdata.nilai_psikotest, cdata.jumlah_pengikut,  color='orange')
plt.xlabel("nilai_psikotest")
plt.ylabel("Pengikut")
plt.show()

# %%
#Membagi data

msk = np.random.rand(len(data)) < 0.8
train = cdata[msk]
test = cdata[~msk]

# %%
plt.scatter(train.nilai_psikotest, train.jumlah_pengikut,  color='blue')
plt.xlabel("Nilai Psikotest")
plt.ylabel("Pengikut")
plt.show()

# %%
#Membuat model regresi
regr = LinearRegression()
train_x = np.asanyarray(train[['nilai_psikotest']])
train_y = np.asanyarray(train[['jumlah_pengikut']])
regr.fit (train_x, train_y)

# Koefisien model
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[0.06152494]]
# Intercept:  [85.43946385]

# %%
#Plot hasil regresi

plt.scatter(train.nilai_psikotest, train.jumlah_pengikut,  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("Nilai Psikotest")
plt.ylabel("Pengikut")
# Out:
# Text(0, 0.5, 'Pengikut')

# %%
#Menghitung error

from sklearn.metrics import r2_score

test_x = np.asanyarray(test[['nilai_psikotest']])
test_y = np.asanyarray(test[['jumlah_pengikut']])
test_y_ = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y_ , test_y) )
# Out:
# Mean absolute error: 6.11
# Residual sum of squares (MSE): 39.73
# R2-score: -5.80
